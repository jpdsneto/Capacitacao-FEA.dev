# %% [markdown]
# # Inflação no Brasil (2003-2022)

# %% [markdown]
# **Neste projeto vamos analisar a evolução da inflação no Brasil, medida pelo IPCA (Índice de Preços ao Consumidor Amplo), que considera uma cesta de consumo ponderada para famílias com uma renda entre 1 e 40 salários mínimos.
# O intúito final do projeto é identificar o comportamento nos preços dos diferentes itens que compõe o índice.**

# %%
# importando as bibliotecas necessárias
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **Trabalharemos com um banco de dados com as taxas de variação do IPCA proveniente do registro de séries temporais do Banco Central do Brasil. No excel, criamos um índice numérico (2003 = 100) para o IPCA e cada um de seus itens.**

# %%
# importando dados
ipca = pd.read_csv('ipca.csv')
display(ipca)
# Out:
#         Date  geral  alimentos  habitacao  artigos_residencia  vestuario  \
# 0    01/2003   2.25       2.15       1.76                1.90       0.94
# 1    02/2003   1.57       1.22       0.18                1.57       0.11
# 2    03/2003   1.23       1.66       1.09                1.19       0.60
# 3    04/2003   0.97       1.01       1.95                0.82       1.03
# 4    05/2003   0.61       0.63       2.27                0.29       1.14
# ..       ...    ...        ...        ...                 ...        ...
# 230  03/2022   1.62       2.42       1.15                0.57       1.82
# 231  04/2022   1.06       2.06      -1.14                1.53       1.26
# 232  05/2022   0.47       0.48      -1.70                0.66       2.11
# 233  06/2022   0.67       0.80       0.41                0.55       1.67
# 234  07/2022  -0.68       1.30      -1.05                0.12       0.58
#
#      transporte  comunicacao  saude  gastos_pessoais  ...  geral_indice  \
# 0          4.20         0.32   1.44             1.94  ...        100.00
# 1          3.00         3.24   0.67             0.64  ...        101.57
# 2          0.70         1.58   2.39             0.72  ...        102.82
# 3          0.50         0.14   1.54             0.35  ...        103.82
# 4         -0.32         0.03   0.71             0.11  ...        104.45
# ..          ...          ...    ...              ...  ...           ...
# 230        3.02        -0.05   0.88             0.59  ...        302.83
# 231        1.91         0.08   1.77             0.48  ...        306.04
# 232        1.34         0.72   1.01             0.52  ...        307.48
# 233        0.57         0.16   1.24             0.49  ...        309.54
# 234       -4.51         0.07   0.49             1.13  ...        307.43
#
#      alimentos_indice  habitacao_indice  artigos_residencia_indice  \
# 0              100.00            100.00                     100.00
# 1              101.22            100.18                     101.57
# 2              102.90            101.27                     102.78
# 3              103.94            103.25                     103.62
# 4              104.59            105.59                     103.92
# ..                ...               ...                        ...
# 230            372.48            336.79                     183.56
# 231            380.15            332.95                     186.37
# 232            381.98            327.29                     187.60
# 233            385.03            328.63                     188.64
# 234            390.04            325.18                     188.86
#
#      vestuario_indice  transporte_indice  comunicacao_indice  saude_indice  \
# 0              100.00             100.00              100.00        100.00
# 1              100.11             103.00              103.24        100.67
# 2              100.71             103.72              104.87        103.08
# 3              101.75             104.24              105.02        104.66
# 4              102.91             103.91              105.05        105.41
# ..                ...                ...                 ...           ...
# 230            274.24             259.50              172.56        311.67
# 231            277.70             264.46              172.70        317.18
# 232            283.56             268.00              173.95        320.39
# 233            288.30             269.53              174.22        324.36
# 234            289.97             257.38              174.35        325.95
#
#      gastos_pessoais_indice  educacao_indice
# 0                    100.00           100.00
# 1                    100.64           105.64
# 2                    101.36           106.61
# 3                    101.72           107.07
# 4                    101.83           107.31
# ..                      ...              ...
# 230                  352.86           355.06
# 231                  354.55           355.28
# 232                  356.40           355.42
# 233                  358.14           355.74
# 234                  362.19           355.95
#
# [235 rows x 21 columns]

# %%
# converter coluna com as datas para o formato datetime64
datas = pd.to_datetime(ipca['Date'])
ipca['Date'] = datas
# transformando a coluna data na coluna índice do dataframe
ipca = ipca.set_index('Date')
display(ipca.head())
# Out:
#             geral  alimentos  habitacao  artigos_residencia  vestuario  \
# Date
# 2003-01-01   2.25       2.15       1.76                1.90       0.94
# 2003-02-01   1.57       1.22       0.18                1.57       0.11
# 2003-03-01   1.23       1.66       1.09                1.19       0.60
# 2003-04-01   0.97       1.01       1.95                0.82       1.03
# 2003-05-01   0.61       0.63       2.27                0.29       1.14
#
#             transporte  comunicacao  saude  gastos_pessoais  educacao  \
# Date
# 2003-01-01        4.20         0.32   1.44             1.94      1.23
# 2003-02-01        3.00         3.24   0.67             0.64      5.64
# 2003-03-01        0.70         1.58   2.39             0.72      0.92
# 2003-04-01        0.50         0.14   1.54             0.35      0.43
# 2003-05-01       -0.32         0.03   0.71             0.11      0.22
#
#             geral_indice  alimentos_indice  habitacao_indice  \
# Date
# 2003-01-01        100.00            100.00            100.00
# 2003-02-01        101.57            101.22            100.18
# 2003-03-01        102.82            102.90            101.27
# 2003-04-01        103.82            103.94            103.25
# 2003-05-01        104.45            104.59            105.59
#
#             artigos_residencia_indice  vestuario_indice  transporte_indice  \
# Date
# 2003-01-01                     100.00            100.00             100.00
# 2003-02-01                     101.57            100.11             103.00
# 2003-03-01                     102.78            100.71             103.72
# 2003-04-01                     103.62            101.75             104.24
# 2003-05-01                     103.92            102.91             103.91
#
#             comunicacao_indice  saude_indice  gastos_pessoais_indice  \
# Date
# 2003-01-01              100.00        100.00                  100.00
# 2003-02-01              103.24        100.67                  100.64
# 2003-03-01              104.87        103.08                  101.36
# 2003-04-01              105.02        104.66                  101.72
# 2003-05-01              105.05        105.41                  101.83
#
#             educacao_indice
# Date
# 2003-01-01           100.00
# 2003-02-01           105.64
# 2003-03-01           106.61
# 2003-04-01           107.07
# 2003-05-01           107.31

# %%
# verificando informações sobre o dataframe
ipca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 235 entries, 2003-01-01 to 2022-07-01
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   geral                      235 non-null    float64
#  1   alimentos                  235 non-null    float64
#  2   habitacao                  235 non-null    float64
#  3   artigos_residencia         235 non-null    float64
#  4   vestuario                  235 non-null    float64
#  5   transporte                 235 non-null    float64
#  6   comunicacao                235 non-null    float64
#  7   saude                      235 non-null    float64
#  8   gastos_pessoais            235 non-null    float64
#  9   educacao                   235 non-null    float64
#  10  geral_indice               235 non-null    float64
#  11  alimentos_indice           235 non-null    float64
#  12  habitacao_indice           235 non-null    float64
#  13  artigos_residencia_indice  235 non-null    float64
#  14  vestuario_indice           235 non-null    float64
#  15  transporte_indice          235 non-null    float64
#  16  comunicacao_indice         235 non-null    float64
#  17  saude_indice               235 non-null    float64
#  18  gastos_pessoais_indice     235 non-null    float64
#  19  educacao_indice            235 non-null    float64
# dtypes: float64(20)
# memory usage: 38.6 KB

# %% [markdown]
# **Note que não há valores nulos e todas as variáveis estão no formato desejado (float64). Assim, podemos continuar.**

# %%
ipca.columns
# Out:
# Index(['geral', 'alimentos', 'habitacao', 'artigos_residencia', 'vestuario',
#        'transporte', 'comunicacao', 'saude', 'gastos_pessoais', 'educacao',
#        'geral_indice', 'alimentos_indice', 'habitacao_indice',
#        'artigos_residencia_indice', 'vestuario_indice', 'transporte_indice',
#        'comunicacao_indice', 'saude_indice', 'gastos_pessoais_indice',
#        'educacao_indice'],
#       dtype='object')

# %%
# Criando dataframe apenas com os índices numéricos
ipca_indices = ipca.drop(['geral', 'alimentos', 'habitacao', 'artigos_residencia', 'vestuario',
       'transporte', 'comunicacao', 'saude', 'gastos_pessoais', 'educacao'], axis=1)
ipca_indices
# Out:
#             geral_indice  alimentos_indice  habitacao_indice  \
# Date
# 2003-01-01        100.00            100.00            100.00
# 2003-02-01        101.57            101.22            100.18
# 2003-03-01        102.82            102.90            101.27
# 2003-04-01        103.82            103.94            103.25
# 2003-05-01        104.45            104.59            105.59
# ...                  ...               ...               ...
# 2022-03-01        302.83            372.48            336.79
# 2022-04-01        306.04            380.15            332.95
# 2022-05-01        307.48            381.98            327.29
# 2022-06-01        309.54            385.03            328.63
# 2022-07-01        307.43            390.04            325.18
#
#             artigos_residencia_indice  vestuario_indice  transporte_indice  \
# Date
# 2003-01-01                     100.00            100.00             100.00
# 2003-02-01                     101.57            100.11             103.00
# 2003-03-01                     102.78            100.71             103.72
# 2003-04-01                     103.62            101.75             104.24
# 2003-05-01                     103.92            102.91             103.91
# ...                               ...               ...                ...
# 2022-03-01                     183.56            274.24             259.50
# 2022-04-01                     186.37            277.70             264.46
# 2022-05-01                     187.60            283.56             268.00
# 2022-06-01                     188.64            288.30             269.53
# 2022-07-01                     188.86            289.97             257.38
#
#             comunicacao_indice  saude_indice  gastos_pessoais_indice  \
# Date
# 2003-01-01              100.00        100.00                  100.00
# 2003-02-01              103.24        100.67                  100.64
# 2003-03-01              104.87        103.08                  101.36
# 2003-04-01              105.02        104.66                  101.72
# 2003-05-01              105.05        105.41                  101.83
# ...                        ...           ...                     ...
# 2022-03-01              172.56        311.67                  352.86
# 2022-04-01              172.70        317.18                  354.55
# 2022-05-01              173.95        320.39                  356.40
# 2022-06-01              174.22        324.36                  358.14
# 2022-07-01              174.35        325.95                  362.19
#
#             educacao_indice
# Date
# 2003-01-01           100.00
# 2003-02-01           105.64
# 2003-03-01           106.61
# 2003-04-01           107.07
# 2003-05-01           107.31
# ...                     ...
# 2022-03-01           355.06
# 2022-04-01           355.28
# 2022-05-01           355.42
# 2022-06-01           355.74
# 2022-07-01           355.95
#
# [235 rows x 10 columns]

# %% [markdown]
# **Podemos visualizar a evolução de cada uma das séries temporáis em um gráfico de linhas.**

# %%
plt.style.use('ggplot')
# plotando o gráfico
ipca_indices.plot(figsize=(20,10))
# definindo labels, título e legenda
plt.xlabel('Ano')
plt.ylabel('IPCA (2003 = 100)')
plt.title('Inflação no Brasil 2003-2022')
plt.legend(['IPCA', 'Alimentos', 'Habitação', 'Artigos de Residência', 'Vestuário', 'Transporte', 'Comunicação', 'Saúde', 'Gastos Pessoais', 'Educação'])

plt.show()

# %% [markdown]
# **Este gráfico é interessante, porém não revela muita coisa. Seria interessante visualizar a evolução individual nos preços de cada item quando comparado ao restante da economia. Para isso, faremos algo como "deflacionar" os índices à partir do índice numérico do IPCA.**

# %%
ipca_def = (ipca_indices.div(ipca_indices['geral_indice'], axis=0) - 1) * 100
ipca_def
# Out:
#             geral_indice  alimentos_indice  habitacao_indice  \
# Date
# 2003-01-01           0.0          0.000000          0.000000
# 2003-02-01           0.0         -0.344590         -1.368514
# 2003-03-01           0.0          0.077806         -1.507489
# 2003-04-01           0.0          0.115585         -0.549027
# 2003-05-01           0.0          0.134035          1.091431
# ...                  ...               ...               ...
# 2022-03-01           0.0         22.999703         11.214213
# 2022-04-01           0.0         24.215789          8.792968
# 2022-05-01           0.0         24.229218          6.442695
# 2022-06-01           0.0         24.387801          6.167216
# 2022-07-01           0.0         26.871158          5.773672
#
#             artigos_residencia_indice  vestuario_indice  transporte_indice  \
# Date
# 2003-01-01                   0.000000          0.000000           0.000000
# 2003-02-01                   0.000000         -1.437432           1.407896
# 2003-03-01                  -0.038903         -2.052130           0.875316
# 2003-04-01                  -0.192641         -1.993835           0.404546
# 2003-05-01                  -0.507420         -1.474390          -0.516994
# ...                               ...               ...                ...
# 2022-03-01                 -39.385134         -9.440940         -14.308358
# 2022-04-01                 -39.102732         -9.260227         -13.586459
# 2022-05-01                 -38.987902         -7.779368         -12.839860
# 2022-06-01                 -39.057957         -6.861795         -12.925632
# 2022-07-01                 -38.568129         -5.679342         -16.280129
#
#             comunicacao_indice  saude_indice  gastos_pessoais_indice  \
# Date
# 2003-01-01            0.000000      0.000000                0.000000
# 2003-02-01            1.644186     -0.886088               -0.915625
# 2003-03-01            1.993776      0.252869               -1.419957
# 2003-04-01            1.155847      0.809093               -2.022732
# 2003-05-01            0.574438      0.919100               -2.508377
# ...                        ...           ...                     ...
# 2022-03-01          -43.017535      2.919130               16.520820
# 2022-04-01          -43.569468      3.640047               15.850869
# 2022-05-01          -43.427215      4.198647               15.909978
# 2022-06-01          -43.716483      4.787750               15.700717
# 2022-07-01          -43.287903      6.024136               17.812185
#
#             educacao_indice
# Date
# 2003-01-01         0.000000
# 2003-02-01         4.007089
# 2003-03-01         3.686053
# 2003-04-01         3.130418
# 2003-05-01         2.738152
# ...                     ...
# 2022-03-01        17.247300
# 2022-04-01        16.089400
# 2022-05-01        15.591258
# 2022-06-01        14.925373
# 2022-07-01        15.782455
#
# [235 rows x 10 columns]

# %%
plt.style.use('ggplot')
# plotando o gráfico
ipca_def.plot(figsize=(20,10))

plt.xlabel('Ano')
plt.ylabel('Aumento real por item do IPCA (%)')
# definindo labels, título e legenda
plt.title('Inflação no Brasil 2003-2022')
plt.legend(['IPCA', 'Alimentos', 'Habitação', 'Artigos de Residência', 'Vestuário', 'Transporte', 'Comunicação', 'Saúde', 'Gastos Pessoais', 'Educação'])

plt.show()

# %% [markdown]
# **Note que agora temos uma reta vermelha sobre o eixo X que é exatamente o Índice do IPCA. Podemos ver que muitos itens ficaram bem mais caros, como educação e gastos pessoais, mas principalmente alimentação, onde houve um crescimento real de quase 30% nos preços. Enquanto isso, outros itens ficaram muito mais baratos, como comunicação e artigos de residência, com uma redução real nos preços de quase 40%.**
